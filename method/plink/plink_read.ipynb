# %%
import dask.dataframe as dd
import dask.array as da
import pandas as pd
import numpy as np
import os
import os.path as osp
from sgkit_plink import pysnptools
from dotenv import load_dotenv; load_dotenv();

# %%
path = osp.join(os.environ['GWAS_TUTORIAL_DIR'], 'HapMap_3_r3_1')
path
# Out:
# '/home/jovyan/work/data/gwas/tutorial/1_QC_GWAS/HapMap_3_r3_1'

# %%
import imp
imp.reload(pysnptools)
# Out:
# <module 'sgkit_plink.pysnptools' from '/home/jovyan/work/repos/sgkit-plink/sgkit_plink/pysnptools.py'>

# %%
# %%time
ds = pysnptools.read_plink(path, bim_sep='\t', fam_sep=' ', bim_int_contig=True)
ds
# Out:
# CPU times: user 1.94 s, sys: 157 ms, total: 2.09 s
# Wall time: 2.09 s
# <xarray.Dataset>
# Dimensions:             (alleles: 2, ploidy: 2, samples: 165, variants: 1457897)
# Dimensions without coordinates: alleles, ploidy, samples, variants
# Data variables:
#     variant/contig      (variants) int16 dask.array<chunksize=(1457897,), meta=np.ndarray>
#     variant/position    (variants) int32 dask.array<chunksize=(1457897,), meta=np.ndarray>
#     variant/alleles     (variants, alleles) |S1 dask.array<chunksize=(1457897, 1), meta=np.ndarray>
#     sample/id           (samples) <U1 dask.array<chunksize=(165,), meta=np.ndarray>
#     call/genotype       (variants, samples, ploidy) int8 dask.array<chunksize=(208271, 165, 2), meta=np.ndarray>
#     call/genotype_mask  (variants, samples, ploidy) bool dask.array<chunksize=(208271, 165, 2), meta=np.ndarray>
#     variant/id          (variants) <U1 dask.array<chunksize=(1457897,), meta=np.ndarray>
# ...

# %%
x = ds['variant/contig'][:5].values
x
# Out:
# array([1, 1, 1, 1, 1], dtype=int16)

# %%
x = ds['variant/alleles'][:5].values
x
# Out:
# array([[b'T', b'C'],
#        [b'G', b'A'],
#        [b'T', b'C'],
#        [b'A', b'G'],
#        [b'A', b'G']], dtype='|S1')

# %%
x[0, 0] == 'T'
# Out:
# False

# %%
ds['sample/id'][:5].values
# Out:
# array(['NA06989', 'NA11891', 'NA11843', 'NA12341', 'NA12739'], dtype='<U7')

# %%
ds['variant/id'][:5].values
# Out:
# array(['rs2185539', 'rs11510103', 'rs11240767', 'rs3131972', 'rs3131969'],
#       dtype='<U10')

# %%
x = ds['call/genotype'][:10, :5].values
x.shape
# Out:
# (10, 5, 2)

# %%
x[3]
# Out:
# array([[0, 1],
#        [0, 1],
#        [0, 0],
#        [0, 1],
#        [0, 0]])
