# %%
https://rgcgithub.github.io/regenie/options/

# %%
# !regenie --help
# Out:
#               |==================================|
#               |           REGENIE v1.0.4.1       |
#               |==================================|
#
# Copyright (c) 2020 Joelle Mbatchou and Jonathan Marchini.
# Distributed under the MIT License.
#
# Options:
#  --help                            print list of available options
#  --helpFull                        print list of all available options
#  --step INT                        specify if fitting null model (=1) or association testing (=2)
#  --bed PREFIX                      prefix to PLINK .bed/.bim/.fam files
#  --pgen PREFIX                     prefix to PLINK2 .pgen/.pvar/.psam files
#  --bgen FILE                       BGEN file
#  --sample FILE                     sample file corresponding to BGEN file
#  --keep FILE                       file listing samples to retain in the analysis
#                                    (no header; starts with FID IID)
# ...

# %%
# %%bash
# EXDIR=$WORK_DIR/repos/regenie/example
# regenie \
#   --step 1 \
#   --bed $EXDIR/example \
#   --exclude $EXDIR/snplist_rm.txt \
#   --c $EXDIR/covariates.txt \
#   --p $EXDIR/phenotype_bin.txt \
#   --remove $EXDIR/fid_iid_to_remove.txt \
#   --b 100 \
#   --bt --lowmem \
#   --o fit_bin_out
# Out:
# Start time: Sat Jul 11 18:46:29 2020
#
#               |==================================|
#               |           REGENIE v1.0.4.1       |
#               |==================================|
#
# Copyright (c) 2020 Joelle Mbatchou and Jonathan Marchini.
# Distributed under the MIT License.
#
# Log of output saved in file : fit_bin_out.log
#
# Command line arguments:
#   --step 1
#   --bed /home/jovyan/work/repos/regenie/example/example
#   --exclude /home/jovyan/work/repos/regenie/example/snplist_rm.txt
#   --c /home/jovyan/work/repos/regenie/example/covariates.txt
#   --p /home/jovyan/work/repos/regenie/example/phenotype_bin.txt
#   --remove /home/jovyan/work/repos/regenie/example/fid_iid_to_remove.txt
#   --b 100
#   --bt
#   --lowmem
#   --o fit_bin_out
#
# Fitting null model
#  * bim              : [/home/jovyan/work/repos/regenie/example/example.bim] n_snps = 1000
#    -removing variants specified in [/home/jovyan/work/repos/regenie/example/snplist_rm.txt]
# ...
